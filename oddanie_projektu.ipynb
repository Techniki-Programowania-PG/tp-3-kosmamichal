# %% [markdown]
# # TECHNIKI PROGRAMOWANIA - Projekt 3
#
# ### Michał Refermat 203680
# ### Kosma Chorążewicz 203320
#
# <br>
#
# ## Zadania projektowe
# ### Wykonane podstawowe funkcjonalności:
#
#
# *   Wizualizacja sygnału z wykorzystaniem biblioteki matplotplusplus,
# *   Generowanie sygnałów o zadanej częstotliwości (sin, cos, prostokątny, piłokształtny).
#
# <br>
#
# ## Generowanie i wizualizacja sygnałów
# <br>
# <br>
#
#
#
#
# *    ### Sygnał sinusoidalny o częstotliwości 5 Hz
#
# <br>
#
# scikit_build_example._core.rysuj_sin(5,0,1,500)
#
#
# <br>
#
#
# ![image.png](data:image/png;base64,...)
#
# <br>
# <br>
#
#
#
#
#
# *   ###   Sygnał cosinusoidalny o częstotliwości 10 Hz
#
# <br>
#
#
# scikit_build_example._core.rysuj_cos(10,0,1000,500)
#
# <br>
#
#
#
# ![cos.png](data:image/png;base64,...)

# %% [markdown]
# <br>
#
#
#
# *   ###    Sygnał prostokątny o częstotliwości 5 Hz
#
# scikit_build_example._core.rysuj_prostokat(5,0,1,200)
#
# <br>
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# <br>
#
#
# *   ###    Sygnał piłokształtny o częstotliwości 5 Hz
#
# scikit_build_example._core.rysuj_piloksztaltny(5,0,1,500)
#
# <br>
#
#
#
#
#
#
# ![image.png](data:image/png;base64,...)
